# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.datasets import load_boston

raw_data = load_boston()
print(raw_data.DESCR)
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
#         - TAX      full-value property-tax rate per $10,000
#         - PTRATIO  pupil-teacher ratio by town
#         - B        1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
#         - LSTAT    % lower status of the population
#         - MEDV     Median value of owner-occupied homes in $1000's
#
#     :Missing Attribute Values: None
#
#     :Creator: Harrison, D. and Rubinfeld, D.L.
#
# This is a copy of UCI ML housing dataset.
# https://archive.ics.uci.edu/ml/machine-learning-databases/housing/
#
#
# This dataset was taken from the StatLib library which is maintained at Carnegie Mellon University.
#
# The Boston house-price data of Harrison, D. and Rubinfeld, D.L. 'Hedonic
# prices and the demand for clean air', J. Environ. Economics & Management,
# vol.5, 81-102, 1978.   Used in Belsley, Kuh & Welsch, 'Regression diagnostics
# ...', Wiley, 1980.   N.B. Various transformations are used in the table on
# pages 244-261 of the latter.
#
# The Boston house-price data has been used in many machine learning papers that address regression
# problems.
#
# .. topic:: References
#
#    - Belsley, Kuh & Welsch, 'Regression diagnostics: Identifying Influential Data and Sources of Collinearity', Wiley, 1980. 244-261.
#    - Quinlan,R. (1993). Combining Instance-Based and Model-Based Learning. In Proceedings on the Tenth International Conference of Machine Learning, 236-243, University of Massachusetts, Amherst. Morgan Kaufmann.

# %%
df = pd.DataFrame(raw_data.data, columns=raw_data.feature_names)
df["PRICE"] = raw_data.target
display(df)
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  PRICE
# 0       15.3  396.90   4.98   24.0
# 1       17.8  396.90   9.14   21.6
# 2       17.8  392.83   4.03   34.7
# 3       18.7  394.63   2.94   33.4
# 4       18.7  396.90   5.33   36.2
# ..       ...     ...    ...    ...
# 501     21.0  391.99   9.67   22.4
# 502     21.0  396.90   9.08   20.6
# 503     21.0  396.90   5.64   23.9
# 504     21.0  393.45   6.48   22.0
# 505     21.0  396.90   7.88   11.9
#
# [506 rows x 14 columns]

# %% [markdown]
# # Binning & Smooting

# %% [markdown]
# Data içinde bulunan "DIS" değişkeninde Evin Bostondaki iş merkezlerine uzaklığı ağırlıklı olarak hesaplanmış. Bu değişkeni farklı yöntemler kullanarak Ayrıklaştırmak istiyoruz.

# %%
# Bu scatterplotı Ayrıklaştırma işlemi yapıldıktan sonraki hali ile karşılaştırabilirsiniz
DIS = df.DIS
x = np.arange(len(DIS))
plt.scatter(x, DIS)
plt.plot()
# Out:
# []

# %% [markdown]
# ### Soru

# %%
# y değişkeninin için pd.cut fonksiyonunu kullanarak df.DIS 'ın ayrıklaştırılmış hali ile doldurun 
# NOT: bins parametresi için "3", labels için "[0,1,2]" ve retbins için "True" değerlerini kullanın
new_DIS, bins = pd.cut(df.DIS, bins=3, retbins=True, labels=[0,1,2])
x = np.arange(len(new_DIS))
plt.scatter(x, new_DIS)

# %% [markdown]
# <b>pd.cut</b> fonksiyonu, değişkeni ayrıklaştırırken aşağıdaki stratejilerden hangisini kullandı?<br>
# -- Equal-frequency(Eşit frekans)<br>
# -- Equal-width (eşit aralıklar)
#
# IPUCU: değişkenin min-max değerlerini ve value_count dağılımlarını kontrol edebilirsiniz.

# %%
print("Min:", df.DIS.min(),"Max:", df.DIS.max())
print("Sınır değerleri:", bins)
print("\n Ayrık değerlerin görülme sayısı")
print(new_DIS.value_counts(), "\n\n")

print("Cevabınızı bu print içine yazabilirsiniz.")
# Out:
# Min: 1.1296 Max: 12.1265
# Sınır değerleri: [ 1.1186031   4.79523333  8.46086667 12.1265    ]
#
#  Ayrık değerlerin görülme sayısı
# 0    365
# 1    125
# 2     16
# Name: DIS, dtype: int64
#
#
# Cevabınızı bu print içine yazabilirsiniz.

# %% [markdown]
# ### Soru

# %%
# aynı işlemi pd.qcut kullanarak yapın
# NOT: q parametresi için "3", labels için "[0,1,2]" ve retbins için "True" değerlerini kullanın
new_DIS, bins = pd.qcut(df.DIS, q=3, retbins=True, labels=[0,1,2])
x = np.arange(len(new_DIS))
plt.scatter(x, new_DIS)

# %% [markdown]
# <b>pd.qcut</b> fonksiyonu, değişkeni ayrıklaştırırken aşağıdaki stratejilerden hangisini kullandı?<br>
# -- Equal-frequency(Eşit frekans)<br>
# -- Equal-width (eşit aralıklar)
#
# IPUCU: değişkenin min-max değerlerini ve value_count dağılımlarını kontrol edebilirsiniz.

# %%
print("Min:", df.DIS.min(),"Max:", df.DIS.max())
print("Sınır değerleri:", bins)
print("\n Ayrık değerlerin görülme sayısı")
print(new_DIS.value_counts(), "\n\n")

print("Cevabınızı bu print içine yazabilirsiniz.")
# Out:
# Min: 1.1296 Max: 12.1265
# Sınır değerleri: [ 1.1296      2.38403333  4.3257     12.1265    ]
#
#  Ayrık değerlerin görülme sayısı
# 2    169
# 0    169
# 1    168
# Name: DIS, dtype: int64
#
#
# Cevabınızı bu print içine yazabilirsiniz.

# %% [markdown]
# # Feature Generation

# %% [markdown]
# Bu bölümde var olan değişkenlerden yeni değişkenler üretelim.

# %%
df2 = df.copy()
df2.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  PRICE
# 0     15.3  396.90   4.98   24.0
# 1     17.8  396.90   9.14   21.6
# 2     17.8  392.83   4.03   34.7
# 3     18.7  394.63   2.94   33.4
# 4     18.7  396.90   5.33   36.2

# %%
# seçtiğiniz iki değişkenin toplamından yeni bir değişken üretin
df2["Sum"] = df2["INDUS"] + df2["DIS"]

# %%
# seçtiğiniz iki değişkenin farkından yeni bir değişken üretin
df2["Minus"] = df2["INDUS"] - df2["DIS"]

# %%
# seçtiğiniz iki değişkenin bölümünden yeni bir değişken üretin
df2["Sum"] = df2["INDUS"] / df2["DIS"]

# %%
# seçtiğiniz iki değişkenin çarpımından yeni bir değişken üretin
df2["Sum"] = df2["INDUS"] * df2["DIS"]

# %%
df2.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  PRICE        Sum   Minus
# 0     15.3  396.90   4.98   24.0   9.447900 -1.7800
# 1     17.8  396.90   9.14   21.6  35.117397  2.1029
# 2     17.8  392.83   4.03   34.7  35.117397  2.1029
# 3     18.7  394.63   2.94   33.4  13.215596 -3.8822
# 4     18.7  396.90   5.33   36.2  13.215596 -3.8822

# %% [markdown]
# sklearn kütüphanesindeki PolynomialFeatures'ı kullanarak yeni featurelar üretin (NOT:Hedef değişkeni(PRICE) yeni featureları üretirken kullanmayın.)

# %%
# PolynomialFeatures kullandığınız python kodunu buraya yazabilirsiniz.
df3 = df.copy()
df3 = df3.drop("PRICE", axis=1)

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
pf = PolynomialFeatures()
pd.DataFrame(pf.fit_transform(df3), 
             columns=pf.get_feature_names(df3.columns))
# Out:
#        1     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  ...  \
# 0    1.0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  ...
# 1    1.0  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  ...
# 2    1.0  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  ...
# 3    1.0  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  ...
# 4    1.0  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  ...
# ..   ...      ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  1.0  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  ...
# 502  1.0  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  ...
# 503  1.0  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  ...
# 504  1.0  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  ...
# 505  1.0  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  ...
#
#        TAX^2  TAX PTRATIO      TAX B  TAX LSTAT  PTRATIO^2  PTRATIO B  \
# 0    87616.0       4528.8  117482.40    1474.08     234.09   6072.570
# 1    58564.0       4307.6   96049.80    2211.88     316.84   7064.820
# 2    58564.0       4307.6   95064.86     975.26     316.84   6992.374
# 3    49284.0       4151.4   87607.86     652.68     349.69   7379.581
# 4    49284.0       4151.4   88111.80    1183.26     349.69   7422.030
# ..       ...          ...        ...        ...        ...        ...
# 501  74529.0       5733.0  107013.27    2639.91     441.00   8231.790
# 502  74529.0       5733.0  108353.70    2478.84     441.00   8334.900
# 503  74529.0       5733.0  108353.70    1539.72     441.00   8334.900
# 504  74529.0       5733.0  107411.85    1769.04     441.00   8262.450
# 505  74529.0       5733.0  108353.70    2151.24     441.00   8334.900
#
#      PTRATIO LSTAT          B^2    B LSTAT  LSTAT^2
# 0           76.194  157529.6100  1976.5620  24.8004
# 1          162.692  157529.6100  3627.6660  83.5396
# 2           71.734  154315.4089  1583.1049  16.2409
# 3           54.978  155732.8369  1160.2122   8.6436
# 4           99.671  157529.6100  2115.4770  28.4089
# ..             ...          ...        ...      ...
# 501        203.070  153656.1601  3790.5433  93.5089
# 502        190.680  157529.6100  3603.8520  82.4464
# 503        118.440  157529.6100  2238.5160  31.8096
# 504        136.080  154802.9025  2549.5560  41.9904
# 505        165.480  157529.6100  3127.5720  62.0944
#
# [506 rows x 105 columns]

# %% [markdown]
# # Normalizasyon

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler

# %% [markdown]
# sklearn kütüphanesindeki Min-max scalerı kullanarak datayı normalize edip yeni bir dataframe içine atayın

# %%
# python kodu:
df_mms = df.copy()
mms = MinMaxScaler()
df_mms[df_mms.columns] = mms.fit_transform(df_mms[df_mms.columns])
display(df_mms)
# Out:
#          CRIM    ZN     INDUS  CHAS       NOX        RM       AGE       DIS  \
# 0    0.000000  0.18  0.067815   0.0  0.314815  0.577505  0.641607  0.269203
# 1    0.000236  0.00  0.242302   0.0  0.172840  0.547998  0.782698  0.348962
# 2    0.000236  0.00  0.242302   0.0  0.172840  0.694386  0.599382  0.348962
# 3    0.000293  0.00  0.063050   0.0  0.150206  0.658555  0.441813  0.448545
# 4    0.000705  0.00  0.063050   0.0  0.150206  0.687105  0.528321  0.448545
# ..        ...   ...       ...   ...       ...       ...       ...       ...
# 501  0.000633  0.00  0.420455   0.0  0.386831  0.580954  0.681771  0.122671
# 502  0.000438  0.00  0.420455   0.0  0.386831  0.490324  0.760041  0.105293
# 503  0.000612  0.00  0.420455   0.0  0.386831  0.654340  0.907312  0.094381
# 504  0.001161  0.00  0.420455   0.0  0.386831  0.619467  0.889804  0.114514
# 505  0.000462  0.00  0.420455   0.0  0.386831  0.473079  0.802266  0.125072
#
#           RAD       TAX   PTRATIO         B     LSTAT     PRICE
# 0    0.000000  0.208015  0.287234  1.000000  0.089680  0.422222
# 1    0.043478  0.104962  0.553191  1.000000  0.204470  0.368889
# 2    0.043478  0.104962  0.553191  0.989737  0.063466  0.660000
# 3    0.086957  0.066794  0.648936  0.994276  0.033389  0.631111
# 4    0.086957  0.066794  0.648936  1.000000  0.099338  0.693333
# ..        ...       ...       ...       ...       ...       ...
# 501  0.000000  0.164122  0.893617  0.987619  0.219095  0.386667
# 502  0.000000  0.164122  0.893617  1.000000  0.202815  0.346667
# 503  0.000000  0.164122  0.893617  1.000000  0.107892  0.420000
# 504  0.000000  0.164122  0.893617  0.991301  0.131071  0.377778
# 505  0.000000  0.164122  0.893617  1.000000  0.169702  0.153333
#
# [506 rows x 14 columns]

# %% [markdown]
# sklearn kütüphanesindeki StandardScalerı kullanarak datayı standardize edip yeni bir dataframe içine atayın

# %%
# python kodu:
df_ss = df.copy()
ss = StandardScaler()
df_ss[df_ss.columns] = ss.fit_transform(df_ss[df_ss.columns])
display(df_ss)
# Out:
#          CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# 0   -0.419782  0.284830 -1.287909 -0.272599 -0.144217  0.413672 -0.120013
# 1   -0.417339 -0.487722 -0.593381 -0.272599 -0.740262  0.194274  0.367166
# 2   -0.417342 -0.487722 -0.593381 -0.272599 -0.740262  1.282714 -0.265812
# 3   -0.416750 -0.487722 -1.306878 -0.272599 -0.835284  1.016303 -0.809889
# 4   -0.412482 -0.487722 -1.306878 -0.272599 -0.835284  1.228577 -0.511180
# ..        ...       ...       ...       ...       ...       ...       ...
# 501 -0.413229 -0.487722  0.115738 -0.272599  0.158124  0.439316  0.018673
# 502 -0.415249 -0.487722  0.115738 -0.272599  0.158124 -0.234548  0.288933
# 503 -0.413447 -0.487722  0.115738 -0.272599  0.158124  0.984960  0.797449
# 504 -0.407764 -0.487722  0.115738 -0.272599  0.158124  0.725672  0.736996
# 505 -0.415000 -0.487722  0.115738 -0.272599  0.158124 -0.362767  0.434732
#
#           DIS       RAD       TAX   PTRATIO         B     LSTAT     PRICE
# 0    0.140214 -0.982843 -0.666608 -1.459000  0.441052 -1.075562  0.159686
# 1    0.557160 -0.867883 -0.987329 -0.303094  0.441052 -0.492439 -0.101524
# 2    0.557160 -0.867883 -0.987329 -0.303094  0.396427 -1.208727  1.324247
# 3    1.077737 -0.752922 -1.106115  0.113032  0.416163 -1.361517  1.182758
# 4    1.077737 -0.752922 -1.106115  0.113032  0.441052 -1.026501  1.487503
# ..        ...       ...       ...       ...       ...       ...       ...
# 501 -0.625796 -0.982843 -0.803212  1.176466  0.387217 -0.418147 -0.014454
# 502 -0.716639 -0.982843 -0.803212  1.176466  0.441052 -0.500850 -0.210362
# 503 -0.773684 -0.982843 -0.803212  1.176466  0.441052 -0.983048  0.148802
# 504 -0.668437 -0.982843 -0.803212  1.176466  0.403225 -0.865302 -0.057989
# 505 -0.613246 -0.982843 -0.803212  1.176466  0.441052 -0.669058 -1.157248
#
# [506 rows x 14 columns]

# %% [markdown]
# sklearn kütüphanesindeki RobustScalerı kullanarak datayı standardize edip yeni bir dataframe içine atayın

# %%
# python kodu:
df_rs = df.copy()
rs = RobustScaler()
df_rs[df_rs.columns] = rs.fit_transform(df_rs[df_rs.columns])
display(df_rs)
# Out:
#          CRIM    ZN     INDUS  CHAS       NOX        RM       AGE       DIS  \
# 0   -0.069593  1.44 -0.571650   0.0  0.000000  0.496612 -0.250765  0.285777
# 1   -0.063755  0.00 -0.202943   0.0 -0.394286  0.287940  0.028542  0.569789
# 2   -0.063760  0.00 -0.202943   0.0 -0.394286  1.323171 -0.334353  0.569789
# 3   -0.062347  0.00 -0.581720   0.0 -0.457143  1.069783 -0.646279  0.924391
# 4   -0.052144  0.00 -0.581720   0.0 -0.457143  1.271680 -0.475025  0.924391
# ..        ...   ...       ...   ...       ...       ...       ...       ...
# 501 -0.053930  0.00  0.173509   0.0  0.200000  0.521003 -0.171254 -0.236007
# 502 -0.058759  0.00  0.173509   0.0  0.200000 -0.119919 -0.016310 -0.297887
# 503 -0.054450  0.00  0.173509   0.0  0.200000  1.039973  0.275229 -0.336744
# 504 -0.040867  0.00  0.173509   0.0  0.200000  0.793360  0.240571 -0.265053
# 505 -0.058164  0.00  0.173509   0.0  0.200000 -0.241870  0.067278 -0.227459
#
#       RAD       TAX   PTRATIO         B     LSTAT     PRICE
# 0   -0.20 -0.087855 -1.339286  0.261902 -0.637681  0.351097
# 1   -0.15 -0.227390 -0.446429  0.261902 -0.221889  0.050157
# 2   -0.15 -0.227390 -0.446429  0.066675 -0.732634  1.692790
# 3   -0.10 -0.279070 -0.125000  0.153016 -0.841579  1.529781
# 4   -0.10 -0.279070 -0.125000  0.261902 -0.602699  1.880878
# ..    ...       ...       ...       ...       ...       ...
# 501 -0.20 -0.147287  0.696429  0.026382 -0.168916  0.150470
# 502 -0.20 -0.147287  0.696429  0.261902 -0.227886 -0.075235
# 503 -0.20 -0.147287  0.696429  0.261902 -0.571714  0.338558
# 504 -0.20 -0.147287  0.696429  0.096414 -0.487756  0.100313
# 505 -0.20 -0.147287  0.696429  0.261902 -0.347826 -1.166144
#
# [506 rows x 14 columns]

# %% [markdown]
# # Correlation & Covariance

# %% [markdown]
# Bu hücrede değişkenlerin birbiri ile olan korelasyonları heatmap kullanarak görselleştirildi.<br>
# Aşağıdaki sorular bu görseli incelemeye ve yorumlamaya yönelik olacaktır.

# %%
plt.figure(figsize=(12,12))
sns.heatmap(df.corr(), vmin=-1, vmax=1, square=True, annot=True, fmt='.2f')
plt.show()

# %% [markdown]
# Aşağıda örnek iki değişken için scatter plot çizilmiştir.

# %%
df.plot.scatter("TAX","CHAS")
plt.show()
# scatter plot çizerken buradan kopya çekebilirsiniz :)

# %% [markdown]
# Yukarıdaki heatmapten birbiri ile pozitif yüksek korelasyona sahip iki değişken için scatter plot çiziniz. Bir iki cümle ile görseli yorumlamaya çalışınız. Not:Yorum yaparken değişkenlerin yukarıdaki açıklamalarından faydalanabilirsiniz.

# %%
# python kodu buraya:
sns.scatterplot(x=df.RM, y=df.PRICE)

print("Oda sayısındaki artış fıyatlara da artış olarak yansımaktadır. Dolayısıyla bu iki değişken pozitif korelasyona sahiptir.")
# Out:
# Oda sayısındaki artış fıyatlara da artış olarak yansımaktadır. Dolayısıyla bu iki değişken pozitif korelasyona sahiptir

# %% [markdown]
# Heatmapten faydalanarak negatif korelasyonlu iki değişken için scatter plot çiziniz. Sonucu yorumlayınız

# %%
# python kodu buraya:
sns.scatterplot(x=df.DIS, y=df.NOX)


print("Boston merkezlerine olan uzaklık (DIS), nitrik oksit konsantrasyonu ile (NOX) negatif korelasyona sahiptir."+
     "Merkeze olan uzaklığın artması doğal olarak hava kirliliğinin, nitrik oksit konsantrasyonunun azalmasına sebep olmaktadır.")
# Out:
# Boston merkezlerine olan uzaklık (DIS), nitrik oksit konsantrasyonu ile (NOX) negatif korelasyona sahiptir.Merkeze olan uzaklığın artması doğal olarak hava kirliliğinin, nitrik oksit konsantrasyonunun azalmasına sebep olmaktadır.

# %% [markdown]
# Heatmapten faydalanarak düşük korelasyonlu iki değişken için scatter plot çiziniz. Sonucu yorumlayınız.

# %%
# python kodu buraya:

sns.scatterplot(x=df.RM, y=df.CHAS)

print("Bölgenin Chas Nehrine komsu olup olmaması ile oda sayısı arasında %9 gibi düşük bir pozitif korelasyon bulunmaktadır"+
     "Dolayısıyla oda sayısı ve CHAS değişkeni arasında kayda değer bir etkileşim yoktur.")
# Out:
# Bölgenin Chas Nehrine komsu olup olmaması ile oda sayısı arasında %9 gibi düşük bir pozitif korelasyon bulunmaktadırDolayısıyla oda sayısı ve CHAS değişkeni arasında kayda değer bir etkileşim yoktur.

# %% [markdown]
# ### Soru

# %% [markdown]
# <b>Adım 1 :</b>df.cov() methodunu kullanarak datasetteki covariance değerlerini hesaplayın.<br>
# sns.heatmap ile bu methodu görselleştirin (IPUCU: Yukarıda korelasyon gösteriminde kullanılan yöntemin aynısı)
# heatmap için vmin ve vmax parametrelerini kullanmayın.

# %%
# Heatmap için python kodunu bu hücreye yazın:

plt.figure(figsize=(12,12))
sns.heatmap(df.cov(), square=True, annot=True, fmt='.2f')
plt.show()

# Bilgi: Kovaryans değerinden anlam çıkartmak korelasyona göre daha zor çıkan grafikten bunu farkedebilirsiniz.

# %% [markdown]
# <b>Adım 2 :</b> Şimdi sklearn.preprocessing paketi içindeki StandardScaler objesini kullanarak datayı standardize edin ve bunu ayrı bir dataframede tutun. Standardize edilmiş dataframe objesinin Kovaryans değerini tekrar hesaplatıp görselleştirin.
#
# <br>IPUCU : standardScalerdan gelen dönüştürülmüş datayı tekrar pandas DataFrame objesine çevirin ve bunu yaparken kolon adlarını kaybetmemeye çalışın örn: pd.DataFrame(standardize_numpy_datası, columns=df.columns)

# %%
# Heatmap için python kodunu bu hücreye yazın:
df_ss2 = df.copy()
ss = StandardScaler()
df_ss2[df_ss2.columns] = ss.fit_transform(df_ss2[df_ss2.columns])

plt.figure(figsize=(17,17))
sns.heatmap(df_ss2.cov(), square=True, cbar=True, annot=True, fmt='.1f');
# Bilgi: Ortaya çıkan grafik korelasyon grafiğine benziyor mu? :)

# %%
df_ss2.cov()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.001980 -0.200866  0.407389 -0.056002  0.421805 -0.219681  0.353433
# ZN      -0.200866  1.001980 -0.534885 -0.042781 -0.517627  0.312608 -0.570665
# INDUS    0.407389 -0.534885  1.001980  0.063063  0.765164 -0.392451  0.646055
# CHAS    -0.056002 -0.042781  0.063063  1.001980  0.091383  0.091432  0.086689
# NOX      0.421805 -0.517627  0.765164  0.091383  1.001980 -0.302787  0.732919
# RM      -0.219681  0.312608 -0.392451  0.091432 -0.302787  1.001980 -0.240741
# AGE      0.353433 -0.570665  0.646055  0.086689  0.732919 -0.240741  1.001980
# DIS     -0.380422  0.665724 -0.709429 -0.099372 -0.770753  0.205653 -0.749361
# RAD      0.626744 -0.312566  0.596308 -0.007383  0.612651 -0.210262  0.456925
# TAX      0.583918 -0.315186  0.722187 -0.035657  0.669346 -0.292626  0.507458
# PTRATIO  0.290520 -0.392454  0.384006 -0.121756  0.189307 -0.356205  0.262033
# B       -0.385826  0.175868 -0.357683  0.048885 -0.380803  0.128322 -0.274076
# LSTAT    0.456524 -0.413812  0.604995 -0.054036  0.592049 -0.615024  0.603531
# PRICE   -0.389074  0.361159 -0.484683  0.175607 -0.428167  0.696737 -0.377701
#
#               DIS       RAD       TAX   PTRATIO         B     LSTAT     PRICE
# CRIM    -0.380422  0.626744  0.583918  0.290520 -0.385826  0.456524 -0.389074
# ZN       0.665724 -0.312566 -0.315186 -0.392454  0.175868 -0.413812  0.361159
# INDUS   -0.709429  0.596308  0.722187  0.384006 -0.357683  0.604995 -0.484683
# CHAS    -0.099372 -0.007383 -0.035657 -0.121756  0.048885 -0.054036  0.175607
# NOX     -0.770753  0.612651  0.669346  0.189307 -0.380803  0.592049 -0.428167
# RM       0.205653 -0.210262 -0.292626 -0.356205  0.128322 -0.615024  0.696737
# AGE     -0.749361  0.456925  0.507458  0.262033 -0.274076  0.603531 -0.377701
# DIS      1.001980 -0.495567 -0.535490 -0.232931  0.292089 -0.497980  0.250424
# RAD     -0.495567  1.001980  0.912031  0.465661 -0.445293  0.489644 -0.382382
# TAX     -0.535490  0.912031  1.001980  0.461766 -0.442683  0.545071 -0.469464
# PTRATIO -0.232931  0.465661  0.461766  1.001980 -0.177735  0.374785 -0.508792
# B        0.292089 -0.445293 -0.442683 -0.177735  1.001980 -0.366812  0.334121
# LSTAT   -0.497980  0.489644  0.545071  0.374785 -0.366812  1.001980 -0.739123
# PRICE    0.250424 -0.382382 -0.469464 -0.508792  0.334121 -0.739123  1.001980
